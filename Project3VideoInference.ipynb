# %%
"""
This Notebook does the inferencing:
1)Clone darknet for usage of directory structure
2)Install OpenCV
3)Copy the darknet binary and needed files to Colab
4)Interencing the input video files in local drive and 
  saving the ouput videos back to the local drive
"""
#clone darknet repository 
# %cd /content/
# !rm -fr darknet
# !git clone https://github.com/kriyeng/darknet/
# Out:
# /content
# Cloning into 'darknet'...
# remote: Enumerating objects: 10068, done.
# remote: Total 10068 (delta 0), reused 0 (delta 0), pack-reused 10068
# Receiving objects: 100% (10068/10068), 10.15 MiB | 5.65 MiB/s, done.
# Resolving deltas: 100% (6735/6735), done.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
local_dr="/content/gdrive/My Drive/darknet"
colab_dr="/content/"

def copy2Colab():

  # Copy the Darkent compiled version to the Colab
  # !cp -v "$local_dr"/bin/darknet $colab_dr/darknet/
  # Set execution permissions to Darknet
  # !chmod +x $colab_dr/darknet/darknet

  # create 'data' dir at Colab, copy some files to it
  # !rm -vrf $colab_dr/my_data/
  # !mkdir $colab_dr/my_data/

  # !cp -v "$local_dr"/*.txt $colab_dr/my_data/
  # !cp -v "$local_dr"/*.names $colab_dr/my_data/

copy2Colab()
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# '/content/gdrive/My Drive/darknet/bin/darknet' -> '/content//darknet/darknet'
# '/content/gdrive/My Drive/darknet/test.txt' -> '/content//my_data/test.txt'
# '/content/gdrive/My Drive/darknet/train.txt' -> '/content//my_data/train.txt'
# '/content/gdrive/My Drive/darknet/obj.names' -> '/content//my_data/obj.names'

# %%
# !apt install ffmpeg libopencv-dev libgtk-3-dev python-numpy python3-numpy libdc1394-22 libdc1394-22-dev libjpeg-dev libtiff5-dev libavcodec-dev libavformat-dev libswscale-dev libxine2-dev libgstreamer1.0-dev libgstreamer-plugins-base1.0-dev libv4l-dev libtbb-dev qtbase5-dev libfaac-dev libmp3lame-dev libopencore-amrnb-dev libopencore-amrwb-dev libtheora-dev libvorbis-dev libxvidcore-dev x264 v4l-utils unzip
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libjpeg-dev is already the newest version (8c-2ubuntu8).
# libjpeg-dev set to manually installed.
# libvorbis-dev is already the newest version (1.3.5-4.2).
# libvorbis-dev set to manually installed.
# python-numpy is already the newest version (1:1.13.3-2ubuntu1).
# python-numpy set to manually installed.
# python3-numpy is already the newest version (1:1.13.3-2ubuntu1).
# python3-numpy set to manually installed.
# unzip is already the newest version (6.0-21ubuntu1).
# libdc1394-22 is already the newest version (2.2.5-1).
# libdc1394-22 set to manually installed.
# libdc1394-22-dev is already the newest version (2.2.5-1).
# libdc1394-22-dev set to manually installed.
# libtbb-dev is already the newest version (2017~U7-8).
# libtbb-dev set to manually installed.
# libtiff5-dev is already the newest version (4.0.9-5ubuntu0.3).
# libtiff5-dev set to manually installed.
# ...

# %%
from os import listdir
# %cd /content/darknet

inputs = [ file for file in listdir("/content/gdrive/My Drive/darknet/vids/") if file.endswith(".mp4") ]
print(inputs)

for input in inputs:
  output = input[:-4] + ".avi"
  print(output)
  # !./darknet detector demo "$local_dr"/obj.data "$local_dr"/cfg/yolov3_test.cfg "$local_dr"/weights/yolov3_train_8000_neg.weights -dont_show "$local_dr"/vids/$input -out_filename "$local_dr"/vids/$output -thresh 0.5
# Out:
# Streaming output truncated to the last 5000 lines.
# FPS:19.1
#
#  cvWriteFrame
# Objects:
#
# fire truck: 69%
# bus: 90%
# bus: 50%
#
# FPS:20.8
#
#  cvWriteFrame
# Objects:
#
# fire truck: 54%
# bus: 93%
# bus: 66%
#
# FPS:24.8
#
#  cvWriteFrame
# Objects:
#
# bus: 97%
# bus: 79%
#
# FPS:26.4
#
#  cvWriteFrame
# Objects:
#
# bus: 96%
#
# FPS:24.3
#
#  cvWriteFrame
# Objects:
#
# bus: 98%
#
# FPS:22.8
#
#  cvWriteFrame
# Objects:
#
# bus: 98%
#
# FPS:28.0
#
#  cvWriteFrame
# Objects:
#
# bus: 95%
#
# FPS:26.8
#
#  cvWriteFrame
# Objects:
#
# fire truck: 65%
# bus: 88%
#
# FPS:22.9
#
#  cvWriteFrame
# Objects:
#
# bus: 94% fire truck: 53%
#
# FPS:26.3
#
#  cvWriteFrame
# Objects:
#
# bus: 97%
#
# FPS:26.0
#
#  cvWriteFrame
# Objects:
#
# bus: 95%
#
# FPS:27.6
#
#  cvWriteFrame
# Objects:
#
# bus: 94%
#
# FPS:25.5
#
#  cvWriteFrame
# Objects:
#
# fire truck: 73%
# bus: 85%
#
# FPS:30.4
#
#  cvWriteFrame
# Objects:
#
# fire truck: 71%
# bus: 75%
#
# FPS:26.0
#
#  cvWriteFrame
# ...
